# %% [markdown]
# <a href="https://colab.research.google.com/github/lalafadli/UAS_AI_2023/blob/main/YoutubeCommentsCrawlerV2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <a href="https://www.youtube.com/channel/UC80kXszNqAdWGTHFBcOKVdg"><img src="https://lh3.googleusercontent.com/3BGYLiEKEvFZ0u6eLcDbKvad__jwIRs30D19_ttfwuMv2TrJ3qovD_Lb_HGF4QvSCeVYoE2Ay6Hkfx0wN0LFV1VvILg7XIdrqR7bE9EtnbF2SwYIueV1-B33aomEwjTmkAKDY4TYopVfaSbfsBWzwfOXpoKy_ASFSrjKt_2p_E35fyTkTbES2t9GUnZ25bMjAe_Y4xqfkw-8lRqK9zCYVwlcD_e2YXUlNXs8ubJCHwZp3MAdPL3kWzLMnuVAKsiORvjt_IgCVINNcDAqfak56arvmtg4MXpcbyKSeYK2A33p0jcFnOkgddq3KhABVNqb0PRM7inpysBXMJ7-u7Q__Y4LVGdFh_gTmuPcxHQZXqS10kU_K86bOQtgqY5m9DjJ5Ixd--sxiR4evRr4LnjDH-9L-6Rcu4EZI6LXMxlANCuFGuTLgIIqrq6qgIliinjuxyuwsX-cl-pE_Y3TBcZ5dum52_O8HtkuPo3NOQXD0Pg4ZfQV11CSkeD-82HaONupDREROrrgFOriOYljzSj4438GSaK4IUTfDjP1UFMKnA6QuZGhSA0noStBSeIwTitSUsHbspxGwYm05Of9UiP-vpvhB5zGDUWl2gLpPsXxz6SDNlDGsVFekX81jNOrFnDzj-Me98FgK4AAmW4Of6Z8LN1ZjBw1MdFwGabLN94tHUMg0sPf-UJFbw5XqN0spoltuB8YmAGSyIWLHoC4eVuARcEX=w1659-h300-no?authuser=0" align="center"></a>
# # <center>Crawling Komentar Video Youtube</center>
# <hr>

# %% [markdown]
# **Tujuan** dari program ini adalah melakukan crawling (pengambilan) data komentar pada sebuah video Youtube menggunakan **Youtube Data API v3**. Sebelum mencoba program ini, pastikan Anda sudah memiliki (mengaktifkan) layanan Youtube Data API dan telah membangkitkan **API Key**.
#
# Jika belum memiliki **API KEY**, Anda dapat mengikuti petunjuk singkat sebagai berikut:
# 1. Login ke Google Developer Console (https://console.developers.google.com/)dengan akun Google Anda
# 2. Buat project baru dan lengkapi isian yang diminta.
# 3. Aktifkan Layanan API pada halaman project, dan cari **Youtube Data API v3**.
# 4. Dari halaman dashboard, buat kredential agar API tersebut dapat digunakan. Klik tombol **Buat Kredensial** (**Create Credential**). Lengkapi isian formnya.
# 5. Anda dapat mengakses / melihat API KEY pada tab **Credentials**.

# %% [markdown]
# #1. Import Library

# %%
import pandas as pd
from googleapiclient.discovery import build

# %% [markdown]
# #2. Fungsi untuk crawling komentar

# %%
def video_comments(video_id):
	# empty list for storing reply
	replies = []

	# creating youtube resource object
	youtube = build('youtube', 'v3', developerKey=api_key)

	# retrieve youtube video results
	video_response = youtube.commentThreads().list(part='snippet,replies', videoId=video_id).execute()

	# iterate video response
	while video_response:

		# extracting required info
		# from each result object
		for item in video_response['items']:

			# Extracting comments ()
			published = item['snippet']['topLevelComment']['snippet']['publishedAt']
			user = item['snippet']['topLevelComment']['snippet']['authorDisplayName']

			# Extracting comments
			comment = item['snippet']['topLevelComment']['snippet']['textDisplay']
			likeCount = item['snippet']['topLevelComment']['snippet']['likeCount']

			replies.append([published, user, comment, likeCount])

			# counting number of reply of comment
			replycount = item['snippet']['totalReplyCount']

			# if reply is there
			if replycount>0:
				# iterate through all reply
				for reply in item['replies']['comments']:

					# Extract reply
					published = reply['snippet']['publishedAt']
					user = reply['snippet']['authorDisplayName']
					repl = reply['snippet']['textDisplay']
					likeCount = reply['snippet']['likeCount']

					# Store reply is list
					#replies.append(reply)
					replies.append([published, user, repl, likeCount])

			# print comment with list of reply
			#print(comment, replies, end = '\n\n')

			# empty reply list
			#replies = []

		# Again repeat
		if 'nextPageToken' in video_response:
			video_response = youtube.commentThreads().list(
					part = 'snippet,replies',
					pageToken = video_response['nextPageToken'],
					videoId = video_id
				).execute()
		else:
			break
	#endwhile
	return replies

# %% [markdown]
# #3. Jalankan Proses Crawling

# %%
# isikan dengan api key Anda
api_key = '<<API KEY>>'

# Enter video id
# contoh url video = https://www.youtube.com/watch?v=5tucmKjOGi8
video_id = "5tucmKjOGi8" #isikan dengan kode / ID video

# Call function
comments = video_comments(video_id)

comments
# Out:
# [['2020-12-31T10:56:20Z',
#   'h y',
#   'saat saya klik add gak kebuka kayak gitu',
#   0],
#  ['2021-01-01T06:18:25Z', 'h y', '@Dr. Achmad Solichin okeh', 0],
#  ['2021-01-01T01:57:20Z',
#   'Dr. Achmad Solichin',
#   '@h y mungkin coba kirim screenshot dan lanjut diskusi ke email saya achmatim@<a href="http://gmail.com/">gmail.com</a>',
#   0],
#  ['2021-01-01T01:51:25Z',
#   'h y',
#   '@Dr. Achmad Solichin yang kebukak itu dari program gdevelop nya sendiri',
#   0],
#  ['2021-01-01T01:50:57Z', 'h y', '@Dr. Achmad Solichin nggak', 0],
#  ['2021-01-01T01:47:45Z',
#   'Dr. Achmad Solichin',
#   '@h y apakah ada error yg muncul?',
#   0],
#  ['2022-07-12T21:28:42Z',
#   'Fanzo Fw',
#   'Permisi pak saya mo nanya, kenapa ya?, setiap saya mau memulai game nya, selalu macet?🙏🙏',
#   0],
#  ['2022-07-13T04:16:46Z',
#   'Fanzo Fw',
#   '@Dr. Achmad Solichin itu bang, pas saya pencet tombol kiri kanan kya gerakannya macet gitu?, apa spek leptop saya gk mendukung ya?',
#   0],
#  ['2022-07-12T22:36:21Z', 'Dr. Achmad Solichin', 'Macet gmn ya? Error?', 0],
#  ['2022-05-23T02:14:01Z', 'Bety Kurnia', 'keren pak', 1],
#  ['2022-05-16T04:46:35Z',
#   'Sos Sos',
#   'Pak saya menghargai ilmu dari anda , terimakasih banyak ilmu anda sangat berguna bagi saya',
#   0],
#  ['2022-05-11T16:19:13Z',
#   'Preman Classic ML',
#   'TY pak... salam kenal.. saya Guru di pekalongan,, hahaahah salam kenal..',
#   1],
#  ['2022-05-11T22:51:01Z',
#   'Dr. Achmad Solichin',
#   'Salam kenal juga pak. Sukses untuk kita semua',
#   0],
#  ['2022-01-14T07:57:36Z',
#   'Luni Asri Syahputri',
#   'ini yang aku cari, ini lengkap dan jelas. makasih ya pak',
#   0],
#  ['2022-01-14T08:20:16Z',
#   'Dr. Achmad Solichin',
#   'Terima kasih, semoga bermanfaat',
#   0],
#  ['2021-09-09T13:57:12Z',
#   'A Z',
#   'Pak pada menit ke 11, itu bagaimana cara menggerakan spritenya? Punya saya tidak dapat bergerak padahal saya sudah menambah behavior juga?',
#   1],
#  ['2021-09-09T14:37:39Z',
#   'Dr. Achmad Solichin',
#   'Jangan lupa settingan jenis object nya adalah platformer character ya, coba diperiksa lebih teliti step by step di videonya.',
#   0],
#  ['2021-07-31T06:20:13Z',
#   'Ennizodev',
#   'Terima kasih Pak🙏🏻, ini yg saya cari simple+lengkap, sukses sll ya Pak🙏🏻',
#   1],
#  ['2021-07-31T07:19:50Z', 'Ennizodev', '@Dr. Achmad Solichin Siap pak 🙏🏻', 0],
#  ['2021-07-31T06:27:02Z',
#   'Dr. Achmad Solichin',
#   'Terima kasih atas apresiasi dan kunjuangannya. Simak juga bbrp video terkait game development di channel ini',
#   1],
#  ['2021-07-16T11:01:04Z',
#   'evelinemtj',
#   'Makasih Pak untuk tutorialnya :) buat saya jelas banget!',
#   1],
#  ['2021-07-16T11:28:24Z',
#   'Dr. Achmad Solichin',
#   'Terima kasih atas apresiasinya. Ditunggu tutorial selanjutnya.',
#   0],
#  ['2021-05-04T00:04:37Z', 'Mamen', 'nderek sinau pakdhe', 1],
#  ['2021-05-04T00:54:51Z', 'Dr. Achmad Solichin', 'Monggo sekecaaken', 0],
#  ['2021-03-24T14:09:52Z', 'Thoha Cahya Ash Shoddiqy', 'good', 1],
#  ['2021-02-09T13:49:24Z',
#   'Ahmad S',
#   'Kira2 bapak sudah brapa lama belajar, nampaknya maaf dengan umur bapak yg tidak sepertinya mudah',
#   0],
#  ['2021-02-09T23:03:19Z',
#   'Dr. Achmad Solichin',
#   '@Ahmad S kalo kemudahan, menurut saya sih GDevelop ya, tapi ya tergantung kitanya juga, mana yg lebih nyaman. Dulu saya nyari yg gampang dipelajari oleh anak2 SD sekalipun, pilihannya GDevelop dan scratch.',
#   1],
#  ['2021-02-09T19:59:23Z',
#   'Ahmad S',
#   '@Dr. Achmad Solichin kalau untuk segi kemudahan konsep action event dan interface lebih mudah construct atau gdevelop pak?',
#   0],
#  ['2021-02-09T14:44:56Z',
#   'Dr. Achmad Solichin',
#   '@Ahmad S contoh game edukasi spt apa? Menurut saya, GDevelop sangat baik untuk game developer pemula, untuk mengenalkan konsep skenario game, scene, karakter, dan juga melatih logika berpikir. Jika mau lebih advanced bisa belajar spt Unity.',
#   2],
#  ['2021-02-09T14:37:13Z',
#   'Ahmad S',
#   '@Dr. Achmad Solichin maaf pak, tutorial pembuatan game edukasi baik bhs inggris dan indonesia kok tidak ada ya di gdevelop, malah lebih ke rpg semua',
#   0],
#  ['2021-02-09T14:05:05Z',
#   'Dr. Achmad Solichin',
#   'Kalo belajar GDevelop ga lama, untuk basic 1-2 hari aja udah bisa. Tinggal pengembangan aja.',
#   0],
#  ['2021-01-05T03:08:50Z', 'Ipung DEV Academy', 'nderek belajar pak dosen', 1],
#  ['2020-12-21T12:19:56Z',
#   'Itamara Shofinia',
#   'Untuk download ilustrasi krakter dll di sbelaj mana pak?',
#   2],
#  ['2020-12-21T20:58:22Z',
#   'Itamara Shofinia',
#   '@Dr. Achmad Solichin Baik 🙏 Terima kasih, Pak.',
#   0],
#  ['2020-12-21T20:50:38Z',
#   'Dr. Achmad Solichin',
#   'Unduh karakter dan file2 yang diperlukan di <a href="https://s.id/satfile1">https://s.id/satfile1</a>',
#   1],
#  ['2020-11-07T10:40:08Z', 'MOCHAMAD AL BADERI', 'mas minta nomer hp nya.', 1],
#  ['2020-11-07T11:32:02Z',
#   'Dr. Achmad Solichin',
#   'Silahkan japri ke achmatim@<a href="http://gmail.com/">gmail.com</a>',
#   0],
#  ['2020-09-06T07:42:32Z', 'Ragilt.Net', 'Mantab pak ijin nyimak', 0]]

# %% [markdown]
# #4. Ubah Hasil Crawling ke Dataframe

# %%
df = pd.DataFrame(comments, columns=['publishedAt', 'authorDisplayName', 'textDisplay', 'likeCount'])
df
# Out:
#              publishedAt         authorDisplayName  \
# 0   2020-12-31T10:56:20Z                       h y
# 1   2021-01-01T06:18:25Z                       h y
# 2   2021-01-01T01:57:20Z       Dr. Achmad Solichin
# 3   2021-01-01T01:51:25Z                       h y
# 4   2021-01-01T01:50:57Z                       h y
# 5   2021-01-01T01:47:45Z       Dr. Achmad Solichin
# 6   2022-07-12T21:28:42Z                  Fanzo Fw
# 7   2022-07-13T04:16:46Z                  Fanzo Fw
# 8   2022-07-12T22:36:21Z       Dr. Achmad Solichin
# 9   2022-05-23T02:14:01Z               Bety Kurnia
# 10  2022-05-16T04:46:35Z                   Sos Sos
# 11  2022-05-11T16:19:13Z         Preman Classic ML
# 12  2022-05-11T22:51:01Z       Dr. Achmad Solichin
# 13  2022-01-14T07:57:36Z       Luni Asri Syahputri
# 14  2022-01-14T08:20:16Z       Dr. Achmad Solichin
# 15  2021-09-09T13:57:12Z                       A Z
# 16  2021-09-09T14:37:39Z       Dr. Achmad Solichin
# 17  2021-07-31T06:20:13Z                 Ennizodev
# 18  2021-07-31T07:19:50Z                 Ennizodev
# 19  2021-07-31T06:27:02Z       Dr. Achmad Solichin
# 20  2021-07-16T11:01:04Z                evelinemtj
# 21  2021-07-16T11:28:24Z       Dr. Achmad Solichin
# 22  2021-05-04T00:04:37Z                     Mamen
# 23  2021-05-04T00:54:51Z       Dr. Achmad Solichin
# 24  2021-03-24T14:09:52Z  Thoha Cahya Ash Shoddiqy
# 25  2021-02-09T13:49:24Z                   Ahmad S
# 26  2021-02-09T23:03:19Z       Dr. Achmad Solichin
# 27  2021-02-09T19:59:23Z                   Ahmad S
# 28  2021-02-09T14:44:56Z       Dr. Achmad Solichin
# 29  2021-02-09T14:37:13Z                   Ahmad S
# 30  2021-02-09T14:05:05Z       Dr. Achmad Solichin
# 31  2021-01-05T03:08:50Z         Ipung DEV Academy
# 32  2020-12-21T12:19:56Z          Itamara Shofinia
# 33  2020-12-21T20:58:22Z          Itamara Shofinia
# 34  2020-12-21T20:50:38Z       Dr. Achmad Solichin
# 35  2020-11-07T10:40:08Z        MOCHAMAD AL BADERI
# 36  2020-11-07T11:32:02Z       Dr. Achmad Solichin
# 37  2020-09-06T07:42:32Z                Ragilt.Net
#
#                                           textDisplay  likeCount
# 0            saat saya klik add gak kebuka kayak gitu          0
# 1                           @Dr. Achmad Solichin okeh          0
# 2   @h y mungkin coba kirim screenshot dan lanjut ...          0
# 3   @Dr. Achmad Solichin yang kebukak itu dari pro...          0
# 4                          @Dr. Achmad Solichin nggak          0
# 5                    @h y apakah ada error yg muncul?          0
# 6   Permisi pak saya mo nanya, kenapa ya?, setiap ...          0
# 7   @Dr. Achmad Solichin itu bang, pas saya pencet...          0
# 8                                Macet gmn ya? Error?          0
# 9                                           keren pak          1
# 10  Pak saya menghargai ilmu dari anda , terimakas...          0
# 11  TY pak... salam kenal.. saya Guru di pekalonga...          1
# 12      Salam kenal juga pak. Sukses untuk kita semua          0
# 13  ini yang aku cari, ini lengkap dan jelas. maka...          0
# 14                    Terima kasih, semoga bermanfaat          0
# 15  Pak pada menit ke 11, itu bagaimana cara mengg...          1
# 16  Jangan lupa settingan jenis object nya adalah ...          0
# 17  Terima kasih Pak🙏🏻, ini yg saya cari simple+le...          1
# 18                   @Dr. Achmad Solichin Siap pak 🙏🏻          0
# 19  Terima kasih atas apresiasi dan kunjuangannya....          1
# 20  Makasih Pak untuk tutorialnya :) buat saya jel...          1
# 21  Terima kasih atas apresiasinya. Ditunggu tutor...          0
# 22                                nderek sinau pakdhe          1
# 23                                  Monggo sekecaaken          0
# 24                                               good          1
# 25  Kira2 bapak sudah brapa lama belajar, nampakny...          0
# 26  @Ahmad S kalo kemudahan, menurut saya sih GDev...          1
# 27  @Dr. Achmad Solichin kalau untuk segi kemudaha...          0
# 28  @Ahmad S contoh game edukasi spt apa? Menurut ...          2
# 29  @Dr. Achmad Solichin maaf pak, tutorial pembua...          0
# 30  Kalo belajar GDevelop ga lama, untuk basic 1-2...          0
# 31                           nderek belajar pak dosen          1
# 32  Untuk download ilustrasi krakter dll di sbelaj...          2
# 33     @Dr. Achmad Solichin Baik 🙏 Terima kasih, Pak.          0
# 34  Unduh karakter dan file2 yang diperlukan di <a...          1
# 35                            mas minta nomer hp nya.          1
# 36  Silahkan japri ke achmatim@<a href="http://gma...          0
# 37                             Mantab pak ijin nyimak          0

# %% [markdown]
# #5. Simpan Hasil Crawling ke file CSV

# %%
df.to_csv('youtube-comments.csv', index=False)

# %% [markdown]
# # Ingin belajar lebih banyak lagi?
#
# Banyak video pembelajaran terkait Machine Learning yang disajikan di channel Youtube http://youtube.com/c/AchmadSolichin. Silahkan berkunjung dan jangan lupa **SUBSCRIBE** untuk membantu pengembangan channel dengan video-video berkualitas lainnya.
#
# ## Terima kasih, selamat belajar!
#
# Notebook ini dibuat oleh: <a href = "http://achmatim.net">Dr. Achmad Solichin</a> dengan acuan dari berbagai sumber:
# 1. https://www.geeksforgeeks.org/how-to-extract-youtube-comments-using-youtube-api-python/
#
# <hr>
# Copyright &copy; 2022 [Achmatim.Net](http://achmatim.net). This notebook and its source code are released under the terms of the CC License.​
